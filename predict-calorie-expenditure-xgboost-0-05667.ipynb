# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     📂IMPORTING LIBRARIES📂
# </div>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings as w
w.filterwarnings('ignore')

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin: 20px; padding: 20px; border-radius: 10px; border: 2px solid #4CAF50; background-color: #E6F7E2;">
#     <b>📂 Libraries:</b> Successfully import the recquired library
# </div>

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     ✔️SETTING FOR VISUALISATION AND BACKGROUND✔️
# </div>

# %%
rc = {
    "axes.facecolor": "#F8F8F8",
    "figure.facecolor": "#F8F8F8",
    "axes.edgecolor": "#000000",
    "grid.color": "#EBEBE7" + "30",
    "font.family": "serif",
    "axes.labelcolor": "#000000",
    "xtick.color": "#000000",
    "ytick.color": "#000000",
    "grid.alpha": 0.4,
}

sns.set(rc=rc)
palette = ['#302c36', '#037d97', '#E4591E', '#C09741',
           '#EC5B6D', '#90A6B1', '#6ca957', '#D8E3E2']

from colorama import Style, Fore
blk = Style.BRIGHT + Fore.BLACK
mgt = Style.BRIGHT + Fore.MAGENTA
red = Style.BRIGHT + Fore.RED
blu = Style.BRIGHT + Fore.BLUE
res = Style.RESET_ALL

plt.style.use('fivethirtyeight')

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     📖READING THE TRAIN AND TEST FILE PATH📖
# </div>

# %%
train=pd.read_csv('/kaggle/input/playground-series-s5e5/train.csv')
test=pd.read_csv('/kaggle/input/playground-series-s5e5/test.csv')

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin: 20px; padding: 20px; border-radius: 10px; border: 2px solid #4CAF50; background-color: #E6F7E2;">
#     <b>📂 DataSet:</b> Successfully read the dataset
# </div>

# %%
train.sample(10).style.background_gradient()
# Out:
# <style type="text/css">
# #T_abd62_row0_col0, #T_abd62_row2_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_abd62_row0_col2, #T_abd62_row0_col3, #T_abd62_row0_col4, #T_abd62_row6_col5, #T_abd62_row6_col7, #T_abd62_row6_col8, #T_abd62_row7_col3, #T_abd62_row8_col0, #T_abd62_row8_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_abd62_row0_col5 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_abd62_row0_col6, #T_abd62_row9_col6 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_abd62_row0_col7 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_abd62_row0_col8 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_abd62_row1_col0, #T_abd62_row1_col2, #T_abd62_row1_col6, #T_abd62_row6_col3, #T_abd62_row6_col4, #T_abd62_row7_col5, #T_abd62_row7_col7, #T_abd62_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_abd62_row1_col3 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_abd62_row1_col4 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_abd62_row1_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_abd62_row1_col7, #T_abd62_row2_col6, #T_abd62_row9_col7 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_abd62_row1_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_abd62_row2_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_abd62_row2_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_abd62_row2_col3 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_abd62_row2_col4 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_abd62_row2_col5 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_abd62_row2_col7 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_abd62_row3_col0 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_abd62_row3_col2, #T_abd62_row4_col2, #T_abd62_row7_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_abd62_row3_col3, #T_abd62_row8_col3 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_abd62_row3_col4 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_abd62_row3_col5 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_abd62_row3_col6 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_abd62_row3_col7 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_abd62_row3_col8 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_abd62_row4_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_abd62_row4_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_abd62_row4_col4 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_abd62_row4_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_abd62_row4_col6 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_abd62_row4_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_abd62_row4_col8 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_abd62_row5_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_abd62_row5_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_abd62_row5_col3, #T_abd62_row9_col3 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_abd62_row5_col4 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_abd62_row5_col5, #T_abd62_row8_col5 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_abd62_row5_col6 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_abd62_row5_col7, #T_abd62_row7_col4, #T_abd62_row8_col7 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_abd62_row5_col8 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_abd62_row6_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_abd62_row6_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_abd62_row6_col6 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_abd62_row7_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_abd62_row7_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_abd62_row8_col2 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_abd62_row8_col4 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_abd62_row8_col8 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_abd62_row9_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_abd62_row9_col2 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_abd62_row9_col4 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_abd62_row9_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_abd62_row9_col8 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# </style>
# <table id="T_abd62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abd62_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_abd62_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_abd62_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_abd62_level0_col3" class="col_heading level0 col3" >Height</th>
#       <th id="T_abd62_level0_col4" class="col_heading level0 col4" >Weight</th>
#       <th id="T_abd62_level0_col5" class="col_heading level0 col5" >Duration</th>
#       <th id="T_abd62_level0_col6" class="col_heading level0 col6" >Heart_Rate</th>
#       <th id="T_abd62_level0_col7" class="col_heading level0 col7" >Body_Temp</th>
#       <th id="T_abd62_level0_col8" class="col_heading level0 col8" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abd62_level0_row0" class="row_heading level0 row0" >155336</th>
#       <td id="T_abd62_row0_col0" class="data row0 col0" >155336</td>
#       <td id="T_abd62_row0_col1" class="data row0 col1" >male</td>
#       <td id="T_abd62_row0_col2" class="data row0 col2" >61</td>
#       <td id="T_abd62_row0_col3" class="data row0 col3" >184.000000</td>
#       <td id="T_abd62_row0_col4" class="data row0 col4" >92.000000</td>
#       <td id="T_abd62_row0_col5" class="data row0 col5" >15.000000</td>
#       <td id="T_abd62_row0_col6" class="data row0 col6" >97.000000</td>
#       <td id="T_abd62_row0_col7" class="data row0 col7" >40.500000</td>
#       <td id="T_abd62_row0_col8" class="data row0 col8" >93.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abd62_level0_row1" class="row_heading level0 row1" >89216</th>
#       <td id="T_abd62_row1_col0" class="data row1 col0" >89216</td>
#       <td id="T_abd62_row1_col1" class="data row1 col1" >female</td>
#       <td id="T_abd62_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_abd62_row1_col3" class="data row1 col3" >165.000000</td>
#       <td id="T_abd62_row1_col4" class="data row1 col4" >67.000000</td>
#       <td id="T_abd62_row1_col5" class="data row1 col5" >7.000000</td>
#       <td id="T_abd62_row1_col6" class="data row1 col6" >74.000000</td>
#       <td id="T_abd62_row1_col7" class="data row1 col7" >39.400000</td>
#       <td id="T_abd62_row1_col8" class="data row1 col8" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abd62_level0_row2" class="row_heading level0 row2" >436179</th>
#       <td id="T_abd62_row2_col0" class="data row2 col0" >436179</td>
#       <td id="T_abd62_row2_col1" class="data row2 col1" >male</td>
#       <td id="T_abd62_row2_col2" class="data row2 col2" >24</td>
#       <td id="T_abd62_row2_col3" class="data row2 col3" >183.000000</td>
#       <td id="T_abd62_row2_col4" class="data row2 col4" >91.000000</td>
#       <td id="T_abd62_row2_col5" class="data row2 col5" >6.000000</td>
#       <td id="T_abd62_row2_col6" class="data row2 col6" >87.000000</td>
#       <td id="T_abd62_row2_col7" class="data row2 col7" >39.000000</td>
#       <td id="T_abd62_row2_col8" class="data row2 col8" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abd62_level0_row3" class="row_heading level0 row3" >540648</th>
#       <td id="T_abd62_row3_col0" class="data row3 col0" >540648</td>
#       <td id="T_abd62_row3_col1" class="data row3 col1" >female</td>
#       <td id="T_abd62_row3_col2" class="data row3 col2" >32</td>
#       <td id="T_abd62_row3_col3" class="data row3 col3" >172.000000</td>
#       <td id="T_abd62_row3_col4" class="data row3 col4" >68.000000</td>
#       <td id="T_abd62_row3_col5" class="data row3 col5" >20.000000</td>
#       <td id="T_abd62_row3_col6" class="data row3 col6" >95.000000</td>
#       <td id="T_abd62_row3_col7" class="data row3 col

# %%
test.sample(10).style.background_gradient()
# Out:
# <style type="text/css">
# #T_72758_row0_col0, #T_72758_row0_col2, #T_72758_row0_col4, #T_72758_row1_col3, #T_72758_row1_col5, #T_72758_row1_col6, #T_72758_row1_col7, #T_72758_row3_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_72758_row0_col3 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_72758_row0_col5, #T_72758_row0_col7, #T_72758_row4_col3, #T_72758_row6_col6, #T_72758_row8_col0, #T_72758_row9_col2, #T_72758_row9_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_72758_row0_col6 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_72758_row1_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_72758_row1_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_72758_row1_col4 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_72758_row2_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_72758_row2_col2, #T_72758_row8_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_72758_row2_col3 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_72758_row2_col4, #T_72758_row2_col5, #T_72758_row6_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_72758_row2_col6, #T_72758_row8_col6 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_72758_row2_col7 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_72758_row3_col0 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_72758_row3_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_72758_row3_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_72758_row3_col4, #T_72758_row6_col4 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_72758_row3_col5 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_72758_row3_col6 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_72758_row4_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_72758_row4_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_72758_row4_col4, #T_72758_row8_col4 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_72758_row4_col5, #T_72758_row7_col4, #T_72758_row8_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_72758_row4_col6 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_72758_row4_col7 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_72758_row5_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_72758_row5_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_72758_row5_col3 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_72758_row5_col4, #T_72758_row7_col5 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_72758_row5_col5 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_72758_row5_col6 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_72758_row5_col7, #T_72758_row7_col7 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_72758_row6_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_72758_row6_col2 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_72758_row6_col3, #T_72758_row8_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_72758_row6_col7, #T_72758_row9_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_72758_row7_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_72758_row7_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_72758_row7_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_72758_row7_col6 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_72758_row8_col7 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_72758_row9_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_72758_row9_col5 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_72758_row9_col6 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_72758_row9_col7 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72758_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_72758_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_72758_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_72758_level0_col3" class="col_heading level0 col3" >Height</th>
#       <th id="T_72758_level0_col4" class="col_heading level0 col4" >Weight</th>
#       <th id="T_72758_level0_col5" class="col_heading level0 col5" >Duration</th>
#       <th id="T_72758_level0_col6" class="col_heading level0 col6" >Heart_Rate</th>
#       <th id="T_72758_level0_col7" class="col_heading level0 col7" >Body_Temp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72758_level0_row0" class="row_heading level0 row0" >240596</th>
#       <td id="T_72758_row0_col0" class="data row0 col0" >990596</td>
#       <td id="T_72758_row0_col1" class="data row0 col1" >male</td>
#       <td id="T_72758_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_72758_row0_col3" class="data row0 col3" >192.000000</td>
#       <td id="T_72758_row0_col4" class="data row0 col4" >99.000000</td>
#       <td id="T_72758_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_72758_row0_col6" class="data row0 col6" >90.000000</td>
#       <td id="T_72758_row0_col7" class="data row0 col7" >37.800000</td>
#     </tr>
#     <tr>
#       <th id="T_72758_level0_row1" class="row_heading level0 row1" >110056</th>
#       <td id="T_72758_row1_col0" class="data row1 col0" >860056</td>
#       <td id="T_72758_row1_col1" class="data row1 col1" >male</td>
#       <td id="T_72758_row1_col2" class="data row1 col2" >34</td>
#       <td id="T_72758_row1_col3" class="data row1 col3" >197.000000</td>
#       <td id="T_72758_row1_col4" class="data row1 col4" >93.000000</td>
#       <td id="T_72758_row1_col5" class="data row1 col5" >21.000000</td>
#       <td id="T_72758_row1_col6" class="data row1 col6" >101.000000</td>
#       <td id="T_72758_row1_col7" class="data row1 col7" >40.500000</td>
#     </tr>
#     <tr>
#       <th id="T_72758_level0_row2" class="row_heading level0 row2" >100653</th>
#       <td id="T_72758_row2_col0" class="data row2 col0" >850653</td>
#       <td id="T_72758_row2_col1" class="data row2 col1" >female</td>
#       <td id="T_72758_row2_col2" class="data row2 col2" >40</td>
#       <td id="T_72758_row2_col3" class="data row2 col3" >174.000000</td>
#       <td id="T_72758_row2_col4" class="data row2 col4" >73.000000</td>
#       <td id="T_72758_row2_col5" class="data row2 col5" >8.000000</td>
#       <td id="T_72758_row2_col6" class="data row2 col6" >88.000000</td>
#       <td id="T_72758_row2_col7" class="data row2 col7" >39.500000</td>
#     </tr>
#     <tr>
#       <th id="T_72758_level0_row3" class="row_heading level0 row3" >130504</th>
#       <td id="T_72758_row3_col0" class="data row3 col0" >880504</td>
#       <td id="T_72758_row3_col1" class="data row3 col1" >female</td>
#       <td id="T_72758_row3_col2" class="data row3 col2" >41</td>
#       <td id="T_72758_row3_col3" class="data row3 col3" >171.000000</td>
#       <td id="T_72758_row3_col4" class="data row3 col4" >71.000000</td>
#       <td id="T_72758_row3_col5" class="data row3 col5" >17.000000</td>
#       <td id="T_72758_row3_col6" class="data row3 col6" >95.000000</td>
#       <td id="T_72758_row3_col7" class="data row3 col7" >40.500000</td>
#     </tr>
#     <tr>
#       <th id="T_72758_level0_row4" class="row_heading level0 row4" >206803</th>
#       <td id="T_72758_row4_col0" class="data row4 col0" >956803</td>
#       <td id="T_72758_row4_col1" class="data row4 col1" >female</td>
#       <td id="T_72758_row4_col2" class="data row4 col2" >53</td>
#       <td id="T_72758_row4_col3" class="data row4 col3" >159.000000</td>
#       <td id="T_72758_row4_col4" class="data row4 col4" >62.000000</td>
#       <td id="T_72758_row4_col5" class="data row4 col5" >3.000000</td>
#       <td id="T_72758_row4_col6" class="data row4 col6" >87.000000</td>
#       <td id="T_72758_row4_col7" class="data row4 col7" >38.600000</td>
#     </tr>
#     <tr>
#       <th id="T_72758_level0_row5" class="row_heading level0 row5" >45604</th>
#       <td id="T_72758_row5_col0" class="data row5 col0" >795604</td>
#       <td id="T_72758_row5_col1" class="data row5 col1" >male</td>
#       <td id="T_72758_row5_col

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     🔍INFORMATION ABOUT TRAIN AND TEST DATA🔍
# </div>

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          750000 non-null  int64
#  1   Sex         750000 non-null  object
#  2   Age         750000 non-null  int64
#  3   Height      750000 non-null  float64
#  4   Weight      750000 non-null  float64
#  5   Duration    750000 non-null  float64
#  6   Heart_Rate  750000 non-null  float64
#  7   Body_Temp   750000 non-null  float64
#  8   Calories    750000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 51.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          250000 non-null  int64
#  1   Sex         250000 non-null  object
#  2   Age         250000 non-null  int64
#  3   Height      250000 non-null  float64
#  4   Weight      250000 non-null  float64
#  5   Duration    250000 non-null  float64
#  6   Heart_Rate  250000 non-null  float64
#  7   Body_Temp   250000 non-null  float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 15.3+ MB

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#      📖STATICAL INFORMATION ABOUT TRAIN AND TEST DATA📖
# </div>

# %%
train.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_f6493_row0_col0, #T_f6493_row0_col3, #T_f6493_row1_col0, #T_f6493_row1_col1, #T_f6493_row1_col2, #T_f6493_row1_col4, #T_f6493_row1_col5, #T_f6493_row1_col6, #T_f6493_row1_col7, #T_f6493_row2_col0, #T_f6493_row2_col1, #T_f6493_row2_col2, #T_f6493_row2_col4, #T_f6493_row2_col5, #T_f6493_row2_col6, #T_f6493_row2_col7, #T_f6493_row3_col0, #T_f6493_row3_col1, #T_f6493_row3_col2, #T_f6493_row3_col4, #T_f6493_row3_col5, #T_f6493_row3_col6, #T_f6493_row3_col7, #T_f6493_row4_col0, #T_f6493_row4_col1, #T_f6493_row4_col2, #T_f6493_row4_col4, #T_f6493_row4_col5, #T_f6493_row4_col6, #T_f6493_row4_col7, #T_f6493_row5_col0, #T_f6493_row5_col1, #T_f6493_row5_col2, #T_f6493_row5_col4, #T_f6493_row5_col5, #T_f6493_row5_col6, #T_f6493_row5_col7, #T_f6493_row6_col0, #T_f6493_row6_col1, #T_f6493_row6_col2, #T_f6493_row6_col4, #T_f6493_row6_col5, #T_f6493_row6_col6, #T_f6493_row6_col7, #T_f6493_row7_col0, #T_f6493_row7_col1, #T_f6493_row7_col2, #T_f6493_row7_col4, #T_f6493_row7_col5, #T_f6493_row7_col6, #T_f6493_row7_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f6493_row0_col1, #T_f6493_row0_col2, #T_f6493_row0_col4, #T_f6493_row0_col5, #T_f6493_row0_col6, #T_f6493_row0_col7, #T_f6493_row2_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f6493_row1_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_f6493_row3_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_f6493_row4_col3, #T_f6493_row7_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_f6493_row5_col3 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_f6493_row6_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# </style>
# <table id="T_f6493">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6493_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f6493_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f6493_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f6493_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f6493_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f6493_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f6493_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f6493_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6493_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_f6493_row0_col0" class="data row0 col0" >750000.000000</td>
#       <td id="T_f6493_row0_col1" class="data row0 col1" >374999.500000</td>
#       <td id="T_f6493_row0_col2" class="data row0 col2" >216506.495284</td>
#       <td id="T_f6493_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f6493_row0_col4" class="data row0 col4" >187499.750000</td>
#       <td id="T_f6493_row0_col5" class="data row0 col5" >374999.500000</td>
#       <td id="T_f6493_row0_col6" class="data row0 col6" >562499.250000</td>
#       <td id="T_f6493_row0_col7" class="data row0 col7" >749999.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_f6493_row1_col0" class="data row1 col0" >750000.000000</td>
#       <td id="T_f6493_row1_col1" class="data row1 col1" >41.420404</td>
#       <td id="T_f6493_row1_col2" class="data row1 col2" >15.175049</td>
#       <td id="T_f6493_row1_col3" class="data row1 col3" >20.000000</td>
#       <td id="T_f6493_row1_col4" class="data row1 col4" >28.000000</td>
#       <td id="T_f6493_row1_col5" class="data row1 col5" >40.000000</td>
#       <td id="T_f6493_row1_col6" class="data row1 col6" >52.000000</td>
#       <td id="T_f6493_row1_col7" class="data row1 col7" >79.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row2" class="row_heading level0 row2" >Height</th>
#       <td id="T_f6493_row2_col0" class="data row2 col0" >750000.000000</td>
#       <td id="T_f6493_row2_col1" class="data row2 col1" >174.697685</td>
#       <td id="T_f6493_row2_col2" class="data row2 col2" >12.824496</td>
#       <td id="T_f6493_row2_col3" class="data row2 col3" >126.000000</td>
#       <td id="T_f6493_row2_col4" class="data row2 col4" >164.000000</td>
#       <td id="T_f6493_row2_col5" class="data row2 col5" >174.000000</td>
#       <td id="T_f6493_row2_col6" class="data row2 col6" >185.000000</td>
#       <td id="T_f6493_row2_col7" class="data row2 col7" >222.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row3" class="row_heading level0 row3" >Weight</th>
#       <td id="T_f6493_row3_col0" class="data row3 col0" >750000.000000</td>
#       <td id="T_f6493_row3_col1" class="data row3 col1" >75.145668</td>
#       <td id="T_f6493_row3_col2" class="data row3 col2" >13.982704</td>
#       <td id="T_f6493_row3_col3" class="data row3 col3" >36.000000</td>
#       <td id="T_f6493_row3_col4" class="data row3 col4" >63.000000</td>
#       <td id="T_f6493_row3_col5" class="data row3 col5" >74.000000</td>
#       <td id="T_f6493_row3_col6" class="data row3 col6" >87.000000</td>
#       <td id="T_f6493_row3_col7" class="data row3 col7" >132.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row4" class="row_heading level0 row4" >Duration</th>
#       <td id="T_f6493_row4_col0" class="data row4 col0" >750000.000000</td>
#       <td id="T_f6493_row4_col1" class="data row4 col1" >15.421015</td>
#       <td id="T_f6493_row4_col2" class="data row4 col2" >8.354095</td>
#       <td id="T_f6493_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_f6493_row4_col4" class="data row4 col4" >8.000000</td>
#       <td id="T_f6493_row4_col5" class="data row4 col5" >15.000000</td>
#       <td id="T_f6493_row4_col6" class="data row4 col6" >23.000000</td>
#       <td id="T_f6493_row4_col7" class="data row4 col7" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row5" class="row_heading level0 row5" >Heart_Rate</th>
#       <td id="T_f6493_row5_col0" class="data row5 col0" >750000.000000</td>
#       <td id="T_f6493_row5_col1" class="data row5 col1" >95.483995</td>
#       <td id="T_f6493_row5_col2" class="data row5 col2" >9.449845</td>
#       <td id="T_f6493_row5_col3" class="data row5 col3" >67.000000</td>
#       <td id="T_f6493_row5_col4" class="data row5 col4" >88.000000</td>
#       <td id="T_f6493_row5_col5" class="data row5 col5" >95.000000</td>
#       <td id="T_f6493_row5_col6" class="data row5 col6" >103.000000</td>
#       <td id="T_f6493_row5_col7" class="data row5 col7" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row6" class="row_heading level0 row6" >Body_Temp</th>
#       <td id="T_f6493_row6_col0" class="data row6 col0" >750000.000000</td>
#       <td id="T_f6493_row6_col1" class="data row6 col1" >40.036253</td>
#       <td id="T_f6493_row6_col2" class="data row6 col2" >0.779875</td>
#       <td id="T_f6493_row6_col3" class="data row6 col3" >37.100000</td>
#       <td id="T_f6493_row6_col4" class="data row6 col4" >39.600000</td>
#       <td id="T_f6493_row6_col5" class="data row6 col5" >40.300000</td>
#       <td id="T_f6493_row6_col6" class="data row6 col6" >40.700000</td>
#       <td id="T_f6493_row6_col7" class="data row6 col7" >41.500000</td>
#     </tr>
#     <tr>
#       <th id="T_f6493_level0_row7" class="row_heading level0 row7" >Calories</th>
#       <td id="T_f6493_row7_col0" class="data row7 col0" >750000.000000</td>
#       <td id="T_f6493_row7_col1" class="data row7 col1" >88.282781</td>
#       <td id="T_f6493_row7_col2" class="data row7 col2" >62.395349</td>
#       <td id="T_f6493_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_f6493_row7_col4" class="data row7 col4" >34.000000</td>
#       <td id="T_f6493_row7_col5" class="data row7 col5" >77.000000</td>
#       <td id="T_f6493_row7_col6" class="data row7 col6" >136.000000</td>
#       <td id="T_f6493_row7_col7" class="data row7 col7" >314.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
test.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_2f136_row0_col0, #T_2f136_row1_col0, #T_2f136_row1_col1, #T_2f136_row1_col2, #T_2f136_row1_col3, #T_2f136_row1_col4, #T_2f136_row1_col5, #T_2f136_row1_col6, #T_2f136_row1_col7, #T_2f136_row2_col0, #T_2f136_row2_col1, #T_2f136_row2_col2, #T_2f136_row2_col3, #T_2f136_row2_col4, #T_2f136_row2_col5, #T_2f136_row2_col6, #T_2f136_row2_col7, #T_2f136_row3_col0, #T_2f136_row3_col1, #T_2f136_row3_col2, #T_2f136_row3_col3, #T_2f136_row3_col4, #T_2f136_row3_col5, #T_2f136_row3_col6, #T_2f136_row3_col7, #T_2f136_row4_col0, #T_2f136_row4_col1, #T_2f136_row4_col2, #T_2f136_row4_col3, #T_2f136_row4_col4, #T_2f136_row4_col5, #T_2f136_row4_col6, #T_2f136_row4_col7, #T_2f136_row5_col0, #T_2f136_row5_col1, #T_2f136_row5_col2, #T_2f136_row5_col3, #T_2f136_row5_col4, #T_2f136_row5_col5, #T_2f136_row5_col6, #T_2f136_row5_col7, #T_2f136_row6_col0, #T_2f136_row6_col1, #T_2f136_row6_col2, #T_2f136_row6_col3, #T_2f136_row6_col4, #T_2f136_row6_col5, #T_2f136_row6_col6, #T_2f136_row6_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2f136_row0_col1, #T_2f136_row0_col2, #T_2f136_row0_col3, #T_2f136_row0_col4, #T_2f136_row0_col5, #T_2f136_row0_col6, #T_2f136_row0_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f136">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f136_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2f136_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2f136_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2f136_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2f136_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_2f136_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_2f136_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_2f136_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f136_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_2f136_row0_col0" class="data row0 col0" >250000.000000</td>
#       <td id="T_2f136_row0_col1" class="data row0 col1" >874999.500000</td>
#       <td id="T_2f136_row0_col2" class="data row0 col2" >72168.927986</td>
#       <td id="T_2f136_row0_col3" class="data row0 col3" >750000.000000</td>
#       <td id="T_2f136_row0_col4" class="data row0 col4" >812499.750000</td>
#       <td id="T_2f136_row0_col5" class="data row0 col5" >874999.500000</td>
#       <td id="T_2f136_row0_col6" class="data row0 col6" >937499.250000</td>
#       <td id="T_2f136_row0_col7" class="data row0 col7" >999999.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f136_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_2f136_row1_col0" class="data row1 col0" >250000.000000</td>
#       <td id="T_2f136_row1_col1" class="data row1 col1" >41.452464</td>
#       <td id="T_2f136_row1_col2" class="data row1 col2" >15.177769</td>
#       <td id="T_2f136_row1_col3" class="data row1 col3" >20.000000</td>
#       <td id="T_2f136_row1_col4" class="data row1 col4" >28.000000</td>
#       <td id="T_2f136_row1_col5" class="data row1 col5" >40.000000</td>
#       <td id="T_2f136_row1_col6" class="data row1 col6" >52.000000</td>
#       <td id="T_2f136_row1_col7" class="data row1 col7" >79.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f136_level0_row2" class="row_heading level0 row2" >Height</th>
#       <td id="T_2f136_row2_col0" class="data row2 col0" >250000.000000</td>
#       <td id="T_2f136_row2_col1" class="data row2 col1" >174.725624</td>
#       <td id="T_2f136_row2_col2" class="data row2 col2" >12.822039</td>
#       <td id="T_2f136_row2_col3" class="data row2 col3" >127.000000</td>
#       <td id="T_2f136_row2_col4" class="data row2 col4" >164.000000</td>
#       <td id="T_2f136_row2_col5" class="data row2 col5" >174.000000</td>
#       <td id="T_2f136_row2_col6" class="data row2 col6" >185.000000</td>
#       <td id="T_2f136_row2_col7" class="data row2 col7" >219.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f136_level0_row3" class="row_heading level0 row3" >Weight</th>
#       <td id="T_2f136_row3_col0" class="data row3 col0" >250000.000000</td>
#       <td id="T_2f136_row3_col1" class="data row3 col1" >75.147712</td>
#       <td id="T_2f136_row3_col2" class="data row3 col2" >13.979513</td>
#       <td id="T_2f136_row3_col3" class="data row3 col3" >39.000000</td>
#       <td id="T_2f136_row3_col4" class="data row3 col4" >63.000000</td>
#       <td id="T_2f136_row3_col5" class="data row3 col5" >74.000000</td>
#       <td id="T_2f136_row3_col6" class="data row3 col6" >87.000000</td>
#       <td id="T_2f136_row3_col7" class="data row3 col7" >126.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f136_level0_row4" class="row_heading level0 row4" >Duration</th>
#       <td id="T_2f136_row4_col0" class="data row4 col0" >250000.000000</td>
#       <td id="T_2f136_row4_col1" class="data row4 col1" >15.415428</td>
#       <td id="T_2f136_row4_col2" class="data row4 col2" >8.349133</td>
#       <td id="T_2f136_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_2f136_row4_col4" class="data row4 col4" >8.000000</td>
#       <td id="T_2f136_row4_col5" class="data row4 col5" >15.000000</td>
#       <td id="T_2f136_row4_col6" class="data row4 col6" >23.000000</td>
#       <td id="T_2f136_row4_col7" class="data row4 col7" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f136_level0_row5" class="row_heading level0 row5" >Heart_Rate</th>
#       <td id="T_2f136_row5_col0" class="data row5 col0" >250000.000000</td>
#       <td id="T_2f136_row5_col1" class="data row5 col1" >95.479084</td>
#       <td id="T_2f136_row5_col2" class="data row5 col2" >9.450161</td>
#       <td id="T_2f136_row5_col3" class="data row5 col3" >67.000000</td>
#       <td id="T_2f136_row5_col4" class="data row5 col4" >88.000000</td>
#       <td id="T_2f136_row5_col5" class="data row5 col5" >95.000000</td>
#       <td id="T_2f136_row5_col6" class="data row5 col6" >103.000000</td>
#       <td id="T_2f136_row5_col7" class="data row5 col7" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2f136_level0_row6" class="row_heading level0 row6" >Body_Temp</th>
#       <td id="T_2f136_row6_col0" class="data row6 col0" >250000.000000</td>
#       <td id="T_2f136_row6_col1" class="data row6 col1" >40.036093</td>
#       <td id="T_2f136_row6_col2" class="data row6 col2" >0.778448</td>
#       <td id="T_2f136_row6_col3" class="data row6 col3" >37.100000</td>
#       <td id="T_2f136_row6_col4" class="data row6 col4" >39.600000</td>
#       <td id="T_2f136_row6_col5" class="data row6 col5" >40.300000</td>
#       <td id="T_2f136_row6_col6" class="data row6 col6" >40.600000</td>
#       <td id="T_2f136_row6_col7" class="data row6 col7" >41.500000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     🔍NULL VALUE CHECK IN TRAIN AND TEST DATA🔍
# </div>

# %%
sns.displot(data = train.isnull().melt(value_name='missing'),
           y = 'variable',
           hue = 'missing',multiple = "fill",height = 8,aspect = 1.6)
plt.axvline(0.4,color = 'r')
plt.title("Null values in train data",fontsize = 13)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin: 20px; padding: 20px; border-radius: 10px; border: 2px solid #4CAF50; background-color: skyblue;">
# <b>🔍 Information:</b> No null value present in train data
# </div>

# %%
sns.displot(data = test.isnull().melt(value_name='missing'),
           y = 'variable',
           hue = 'missing',multiple = "fill",height = 8,aspect = 1.6)
plt.axvline(0.4,color = 'r')
plt.title("Null values in train data",fontsize = 13)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success" style="margin: 20px; padding: 20px; border-radius: 10px; border: 2px solid #4CAF50; background-color: skyblue;">
# <b>🔍 Information:</b> No null value present in test data
# </div>

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     ➕Feature Enginerring➕
# </div>

# %%
# Weight_per_Age
train['Weight_per_Age'] = train['Weight'] / (train['Age'] + 1)
test['Weight_per_Age'] = test['Weight'] / (test['Age'] + 1)

# HeartRate per Weight
train['HeartRate_per_kg'] = train['Heart_Rate'] / train['Weight']
test['HeartRate_per_kg'] = test['Heart_Rate'] / test['Weight']
# Duration Per Age
train['Duration_per_age'] = train['Duration'] / (train['Age'] + 1)
test['Duration_per_age'] = test['Duration'] / (test['Age'] + 1 )

# Duration * Heart Rate
train['Duration_heart_rate']=train['Duration']*train['Heart_Rate']
test['Duration_heart_rate']=test['Duration']*test['Heart_Rate']

# Intensity
train['Duration_per_weight']=train['Duration']/train['Weight']
test['Duration_per_weight']=test['Duration']/test['Weight']

# All Durations add and multi
train['duration_sum']=train['Duration_per_weight']+train['Duration_heart_rate']+train['Duration_per_age']
test['duration_sum']=test['Duration_per_weight']+test['Duration_heart_rate']+test['Duration_per_age']

train['duration_multi']=train['Duration_per_weight']*train['Duration_heart_rate']*train['Duration_per_age']
test['duration_multi']=test['Duration_per_weight']*test['Duration_heart_rate']*test['Duration_per_age']

# Converting Height in Meters
train['Height']=train['Height']/100
test['Height']=test['Height']/100

# Creating new column 'BMI'
train['BMI']=train['Weight']/(train['Height'] ** 2)
train['BMI']=train['BMI'].round(2)
test['BMI']=test['Weight']/(test['Height'] ** 2)
test['BMI']=test['BMI'].round(2)

# Mapping Genders
map={'male':0,'female':1}
train['Sex']=train['Sex'].map(map)
test['Sex']=test['Sex'].map(map)

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     🙌Model🙌
# </div>

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_squared_log_error

x = train.drop(columns=['Calories', 'id'])
y = train['Calories']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=7,        
    reg_lambda=1.0,            
    reg_alpha=0.5,            
    subsample=0.8,           
    colsample_bytree=0.8,    
    min_child_weight=10,      
    gamma=0.2,               
    max_delta_step=0,      
    grow_policy='depthwise',
    tree_method='hist',        
    objective='reg:squarederror',
    random_state=42,
    verbosity=0,
    n_jobs=-1   
)

model.fit(x_train, y_train)

y_pred = model.predict(x_test)
y_pred_clipped = np.maximum(0, y_pred)

print(f"MSE: {mean_squared_error(y_test, y_pred_clipped)}")
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred_clipped))
print(f"RMSLE: {rmsle}")
# Out:
# MSE: 12.951098155779208
# RMSLE: 0.06163566734517318

# %%
feature_names = x.columns
raw_importance = model.feature_importances_
normalized_importance = raw_importance / raw_importance.sum()
importance_df = pd.DataFrame({
    'feature': feature_names,
    'IMP': normalized_importance
}).sort_values(by='IMP', ascending=False)
importance_df = importance_df.round(6)

# %%
importance_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_87aa5_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_87aa5_row1_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_87aa5_row2_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_87aa5_row3_col1, #T_87aa5_row4_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_87aa5_row5_col1, #T_87aa5_row6_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_87aa5_row7_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_87aa5_row8_col1, #T_87aa5_row9_col1, #T_87aa5_row10_col1, #T_87aa5_row11_col1, #T_87aa5_row12_col1, #T_87aa5_row13_col1, #T_87aa5_row14_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_87aa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87aa5_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_87aa5_level0_col1" class="col_heading level0 col1" >IMP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87aa5_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_87aa5_row0_col0" class="data row0 col0" >Duration_heart_rate</td>
#       <td id="T_87aa5_row0_col1" class="data row0 col1" >0.713676</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_87aa5_row1_col0" class="data row1 col0" >duration_sum</td>
#       <td id="T_87aa5_row1_col1" class="data row1 col1" >0.230584</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_87aa5_row2_col0" class="data row2 col0" >Duration</td>
#       <td id="T_87aa5_row2_col1" class="data row2 col1" >0.016281</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_87aa5_row3_col0" class="data row3 col0" >Age</td>
#       <td id="T_87aa5_row3_col1" class="data row3 col1" >0.011085</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_87aa5_row4_col0" class="data row4 col0" >Sex</td>
#       <td id="T_87aa5_row4_col1" class="data row4 col1" >0.008785</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87aa5_row5_col0" class="data row5 col0" >Heart_Rate</td>
#       <td id="T_87aa5_row5_col1" class="data row5 col1" >0.005991</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row6" class="row_heading level0 row6" >13</th>
#       <td id="T_87aa5_row6_col0" class="data row6 col0" >duration_multi</td>
#       <td id="T_87aa5_row6_col1" class="data row6 col1" >0.005793</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_87aa5_row7_col0" class="data row7 col0" >Duration_per_age</td>
#       <td id="T_87aa5_row7_col1" class="data row7 col1" >0.003672</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_87aa5_row8_col0" class="data row8 col0" >Weight</td>
#       <td id="T_87aa5_row8_col1" class="data row8 col1" >0.001489</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_87aa5_row9_col0" class="data row9 col0" >Weight_per_Age</td>
#       <td id="T_87aa5_row9_col1" class="data row9 col1" >0.001267</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_87aa5_row10_col0" class="data row10 col0" >Duration_per_weight</td>
#       <td id="T_87aa5_row10_col1" class="data row10 col1" >0.000543</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row11" class="row_heading level0 row11" >8</th>
#       <td id="T_87aa5_row11_col0" class="data row11 col0" >HeartRate_per_kg</td>
#       <td id="T_87aa5_row11_col1" class="data row11 col1" >0.000414</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row12" class="row_heading level0 row12" >2</th>
#       <td id="T_87aa5_row12_col0" class="data row12 col0" >Height</td>
#       <td id="T_87aa5_row12_col1" class="data row12 col1" >0.000183</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row13" class="row_heading level0 row13" >6</th>
#       <td id="T_87aa5_row13_col0" class="data row13 col0" >Body_Temp</td>
#       <td id="T_87aa5_row13_col1" class="data row13 col1" >0.000172</td>
#     </tr>
#     <tr>
#       <th id="T_87aa5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_87aa5_row14_col0" class="data row14 col0" >BMI</td>
#       <td id="T_87aa5_row14_col1" class="data row14 col1" >0.000063</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     😊Model Saving😊
# </div>

# %%
import joblib
joblib.dump(model,'model.joblib')
print('Model saved Successfully')
model_lk=joblib.load('model.joblib')
print('Model loaded Successfully')
# Out:
# Model saved Successfully
# Model loaded Successfully

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#     👍Model Prediction Submission👍
# </div>

# %%
import joblib
import pandas as pd
import numpy as np
import os

model = joblib.load('model.joblib')
print('Model loaded Successfully')

test = test.rename(columns={'duration_multu': 'duration_multi'})

X_test = test.drop(columns=['id'])

y_pred = model.predict(X_test)
y_pred_clipped = np.maximum(0, y_pred)

submission = pd.DataFrame({
    'id': test['id'],
    'Calories': y_pred_clipped
})

submission.to_csv('./submission.csv', index=False)

if os.path.exists('./submission.csv'):
    print('File saved successfully!')
else:
    print('Error: File was not saved.')
# Out:
# Model loaded Successfully
# File saved successfully!

# %%
submission.head().style.background_gradient()
# Out:
# <style type="text/css">
# #T_ef9b6_row0_col0, #T_ef9b6_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ef9b6_row1_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_ef9b6_row1_col1 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_ef9b6_row2_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_ef9b6_row2_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_ef9b6_row3_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_ef9b6_row3_col1, #T_ef9b6_row4_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ef9b6_row4_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef9b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef9b6_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_ef9b6_level0_col1" class="col_heading level0 col1" >Calories</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef9b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef9b6_row0_col0" class="data row0 col0" >750000</td>
#       <td id="T_ef9b6_row0_col1" class="data row0 col1" >27.060564</td>
#     </tr>
#     <tr>
#       <th id="T_ef9b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef9b6_row1_col0" class="data row1 col0" >750001</td>
#       <td id="T_ef9b6_row1_col1" class="data row1 col1" >109.376976</td>
#     </tr>
#     <tr>
#       <th id="T_ef9b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef9b6_row2_col0" class="data row2 col0" >750002</td>
#       <td id="T_ef9b6_row2_col1" class="data row2 col1" >86.894386</td>
#     </tr>
#     <tr>
#       <th id="T_ef9b6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef9b6_row3_col0" class="data row3 col0" >750003</td>
#       <td id="T_ef9b6_row3_col1" class="data row3 col1" >126.347969</td>
#     </tr>
#     <tr>
#       <th id="T_ef9b6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef9b6_row4_col0" class="data row4 col0" >750004</td>
#       <td id="T_ef9b6_row4_col1" class="data row4 col1" >75.924133</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !head submission.csv
# Out:
# id,Calories
# 750000,27.060564
# 750001,109.376976
# 750002,86.89439
# 750003,126.34797
# 750004,75.92413
# 750005,21.821592
# 750006,48.71267
# 750007,6.739776
# 750008,9.917237
